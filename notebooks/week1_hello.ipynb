# %%
print ("Hello, Crypto AI Trader!")
# Out:
# Hello, Crypto AI Trader!

# %%
btc_price = 105990
print(f"My first BTC price: ${btc_price:,}")
# Out:
# My first BTC price: $105,990

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# btc_price              int         105990
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x000001E12D802AC0>
# dataframe_hash         function    <function dataframe_hash at 0x000001E12D803100>
# dtypes_str             function    <function dtypes_str at 0x000001E12D803240>
# get_dataframes         function    <function get_dataframes at 0x000001E12D802840>
# getpass                module      <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x000001E12D802DE0>
# is_data_frame          function    <function is_data_frame at 0x000001E12D802D40>
# json                   module      <module 'json' from 'C:\\<...>\Lib\\json\\__init__.py'>

# %% [markdown]
# ### Topic Overview
# This section covers:
# - The `print()` function for displaying text output.
# - Using **f-strings** for variable input and string formatting (f-strings allow you to embed variables inside strings using curly braces).
# - The `%whos` magic command in Jupyter for listing all active variables.
